# %%
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# ============================================================
# 🟢 LEVEL 1 — PANDAS BASICS
# ============================================================

# Q1. Load and inspect the data
# Load the CSV into a DataFrame and display:
# - First 5 rows
# - Last 5 rows
# - Number of rows and columns
# - Column names
# - Data types of all columns


# Q2. Basic statistics
# Find:
# - Total number of records
# - Total sales
# - Total profit
# - Total quantity sold
# - Average sales
# - Average profit


# Q3. Select columns
# Create a new DataFrame containing only:
# - Customer Name
# - Segment
# - City
# - State
# - Category
# - Sales
# - Profit


# Q4. Filtering
# Find all records where:
# 1. Sales > 500
# 2. Profit > 100
# 3. Discount > 0
# 4. Category == "Furniture"
#
# Then find records where:
# Sales > 500 AND Profit < 0


# Q5. Sorting
# Sort the DataFrame:
# 1. By Sales from highest to lowest
# 2. By Profit from lowest to highest
# 3. By Category ascending and Sales descending


# ============================================================
# 🟢 LEVEL 2 — DATA CLEANING & TRANSFORMATION
# ============================================================

# Q6. Missing values
# Find:
# - Number of missing values in each column
# - Total missing values in the entire DataFrame
# - Columns containing at least one missing value


# Q7. Unique values
# Find:
# - Number of unique customers
# - Number of unique products
# - Number of unique cities
# - Number of unique states
# - Unique categories
# - Unique sub-categories
# - Unique regions


# Q8. value_counts()
# Find the number of records for each:
# - Category
# - Sub-Category
# - Segment
# - Region
# - Ship Mode
# - Profit Status
# - Discount Status


# Q9. Create a new column
# Create a column called "Profit Margin":
#
# Profit Margin = Profit / Sales * 100
#
# Display:
# - Product Name
# - Sales
# - Profit
# - Profit Margin
#
# for the first 10 rows.


# Q10. Use apply()
# Create a column called "Sales Level":
#
# Sales < 100          -> "Low"
# Sales between 100-500 -> "Medium"
# Sales > 500          -> "High"


# ============================================================
# 🟡 LEVEL 3 — GROUPBY
# ============================================================

# Q11. Category analysis
# Calculate total:
# - Sales
# - Profit
# - Quantity
#
# for each Category.


# Q12. Region analysis
# Find the total Sales and Profit for each Region.
#
# Then sort the result by Profit in descending order.


# Q13. Sub-category analysis
# Find the average Sales for every Sub-Category.
#
# Which Sub-Categories have an average Sales value greater than 200?


# Q14. Customer analysis
# Find the top 10 customers by total Sales.
#
# Output:
# - Customer Name
# - Total Sales


# Q15. Customer profitability
# Find:
# - Top 10 customers based on total Profit
# - 10 customers with the lowest total Profit


# Q16. Multiple aggregations
# For each Category, calculate:
# - Total Sales
# - Average Sales
# - Total Profit
# - Average Profit
# - Total Quantity
#
# Use .agg()


# ============================================================
# 🟠 LEVEL 4 — DATE ANALYSIS
# ============================================================

# Q17. Convert dates and extract information
# Convert:
# - Order Date
# - Ship Date
#
# into proper datetime columns.
#
# Then create:
# - Order Year
# - Order Month
# - Order Day


# Q18. Yearly sales
# Calculate total:
# - Sales
# - Profit
# - Quantity
#
# for each Order Year.


# Q19. Monthly sales
# Find total Sales for each month.
#
# Then determine which month has the highest total Sales.


# Q20. Shipping time
# Create a column called "Shipping Days":
#
# Shipping Days = Ship Date - Order Date
#
# Find:
# - Average shipping days
# - Maximum shipping days
# - Minimum shipping days
# - Orders taking more than 5 days
#
# Also identify records where Shipping Days is negative.


# ============================================================
# 🔴 LEVEL 5 — ADVANCED PANDAS
# ============================================================

# Q21. Category + Region
# Create a table showing total Profit for every
# Category × Region combination.
#
# Solve using groupby() or pivot_table().


# Q22. Pivot table
# Create a pivot table where:
# - Rows = Region
# - Columns = Category
# - Values = Sales
# - Aggregation = sum


# Q23. Most profitable products
# Find the top 10 products based on total Profit.
#
# Remember:
# The same product can appear in multiple rows,
# so group the products first.


# Q24. Loss-making products
# Find products where:
#
# Total Sales > 1000
# AND
# Total Profit < 0
#
# Group the data first, then filter the result.


# Q25. Discount analysis
# Calculate the average Profit for each Discount level:
#
# 0%
# 10%
# 20%
# 30%
# 40%
# 50%
#
# Then compare it with the number of records
# at each Discount level.


# ============================================================
# 🔥 LEVEL 6 — REAL DATA ANALYSIS
# ============================================================

# Q26. Category profitability
# For each Category calculate:
# - Total Sales
# - Total Profit
# - Profit Margin
#
# Profit Margin =
# Total Profit / Total Sales * 100


# Q27. Customer purchase behavior
# Find customers who:
# - Have at least 10 orders/records
# - Have total Sales greater than 5000
# - Have positive total Profit


# Q28. Repeat customers
# Find customers who purchased products in more than one year.
#
# Output:
# - Customer Name
# - Number of Years
# - Total Sales


# Q29. Product performance
# For every Sub-Category calculate:
# - Total Sales
# - Total Profit
# - Average Discount
# - Total Quantity
# - Profit Margin
#
# Then identify Sub-Categories with negative total Profit.


# Q30. Business-style analysis
# Find the top 10 States by total Sales.
#
# For those states, show:
# - State
# - Total Sales
# - Total Profit
# - Average Discount
# - Total Quantity
# - Profit Margin
#
# Sort by Total Sales descending.


# ============================================================
# 💀 CHALLENGE QUESTIONS
# ============================================================

# Q31. Best-selling product in each category
# For every Category, find the product with the
# highest total Sales.
#
# Expected output:
# - Category
# - Product Name
# - Total Sales


# Q32. Most profitable customer in each region
# For every Region, find the customer with the
# highest total Profit.


# Q33. Loss percentage
# Calculate Loss Percentage for each Category:
#
# Loss Percentage =
# Number of loss-making records / Total records * 100
#
# A loss-making record means Profit < 0.


# Q34. Discount vs profitability
# For each Discount level calculate:
# - Number of Orders
# - Total Sales
# - Total Profit
# - Average Profit
# - Percentage of loss-making records


# Q35. 🚀 FINAL PANDAS CHALLENGE
#
# Create a complete Sales Performance Summary containing:
#
# - Region
# - Category
# - Total Sales
# - Total Profit
# - Total Quantity
# - Average Discount
# - Profit Margin
# - Number of Orders
#
# Profit Margin =
# Total Profit / Total Sales * 100
#
# Then sort the result by:
# Region ascending
# and Total Sales descending
#
# This question should use:
# - groupby()
# - agg()
# - reset_index()
# - calculated columns
# - sorting
#
# ------------------------------------------------------------
# END OF PANDAS PRACTICE
# ------------------------------------------------------------

# %%
df=pd.read_csv(r"C:\Users\Pratik\Downloads\Superstore.csv",encoding='latin1')

# %%
df
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 1          2  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 2          3  CA-2013-138688   13/06/13  17/06/13    Second Class    DV-13045
# 3          4  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 4          5  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2011-110422   22/01/11  24/01/11    Second Class    TB-21400
# 9990    9991  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9991    9992  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9992    9993  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9993    9994  CA-2014-119914   05/05/14  10/05/14    Second Class    CC-12220
#
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 1       2  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 2       3  CA-2013-138688   13/06/13  17/06/13    Second Class    DV-13045
# 3       4  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 4       5  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Discount Status', 'Profit Status', 'Is Profitable', 'Sales Per Unit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Row ID           9994 non-null   int64
#  1   Order ID         9994 non-null   object
#  2   Order Date       9994 non-null   object
#  3   Ship Date        9994 non-null   object
#  4   Ship Mode        9994 non-null   object
#  5   Customer ID      9994 non-null   object
#  6   Customer Name    9994 non-null   object
#  7   Segment          9994 non-null   object
#  8   Country          9994 non-null   object
#  9   City             9994 non-null   object
#  10  State            9994 non-null   object
#  11  Postal Code      9994 non-null   int64
#  12  Region           9994 non-null   object
#  13  Product ID       9994 non-null   object
#  14  Category         9994 non-null   object
#  15  Sub-Category     9994 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code        0
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# Discount Status    0
# Profit Status      0
# Is Profitable      0
# Sales Per Unit     0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Discount Status, Profit Status, Is Profitable, Sales Per Unit]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.dtypes
# Out:
# Row ID               int64
# Order ID            object
# Order Date          object
# Ship Date           object
# Ship Mode           object
# Customer ID         object
# Customer Name       object
# Segment             object
# Country             object
# City                object
# State               object
# Postal Code          int64
# Region              object
# Product ID          object
# Category            object
# Sub-Category        object
# Product Name        object
# Sales              float64
# Quantity             int64
# Discount           float64
# Profit             float64
# Discount Status     object
# Profit Status       object
# Is Profitable         bool
# Sales Per Unit     float64
# dtype: object

# %%
Total_sales=df['Sales'].sum()

# %%
Total_sales
# Out:
# np.float64(2297200.8603000003)

# %%
Total_profit=df['Profit'].sum()

# %%
Total_profit
# Out:
# np.float64(286397.0217)

# %%
Total_quantity_sold=df['Quantity'].sum()
Total_quantity_sold
# Out:
# np.int64(37873)

# %%
Avg_sales=df['Sales'].mean()
Avg_sales
# Out:
# np.float64(229.85800083049833)

# %%
Avg_profit=df['Profit'].mean()
Avg_profit
# Out:
# np.float64(28.65689630778467)

# %%
df2=df[['Customer Name','Segment',
'City',
'State',
'Category',
'Sales',
'Profit']]

# %%
df2.head()
# Out:
#      Customer Name    Segment             City       State         Category  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        Furniture
# 1      Claire Gute   Consumer        Henderson    Kentucky        Furniture
# 2  Darrin Van Huff  Corporate      Los Angeles  California  Office Supplies
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        Furniture
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  Office Supplies
#
#       Sales    Profit
# 0  261.9600   41.9136
# 1  731.9400  219.5820
# 2   14.6200    6.8714
# 3  957.5775 -383.0310
# 4   22.3680    2.5164

# %%
df2[df2['Sales']>500]
# Out:
#         Customer Name    Segment             City       State  \
# 1         Claire Gute   Consumer        Henderson    Kentucky
# 3      Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 7     Brosina Hoffman   Consumer      Los Angeles  California
# 10    Brosina Hoffman   Consumer      Los Angeles  California
# 11    Brosina Hoffman   Consumer      Los Angeles  California
# ...               ...        ...              ...         ...
# 9931    Keith Herrera   Consumer   San Bernardino  California
# 9942    Maribeth Dona   Consumer          Anaheim  California
# 9947  Helen Wasserman  Corporate     Indianapolis     Indiana
# 9948  Helen Wasserman  Corporate     Indianapolis     Indiana
# 9968  Richard Bierner   Consumer       Plainfield  New Jersey
#
#              Category      Sales    Profit
# 1           Furniture   731.9400  219.5820
# 3           Furniture   957.5775 -383.0310
# 7          Technology   907.1520   90.7152
# 10          Furniture  1706.1840   85.3092
# ...

# %%
df2[df2['Profit']>100]
# Out:
#         Customer Name      Segment           City       State  \
# 1         Claire Gute     Consumer      Henderson    Kentucky
# 13       Irene Maddox     Consumer        Seattle  Washington
# 24        Emily Burns     Consumer           Orem        Utah
# 35          Gene Hale    Corporate     Richardson       Texas
# 54     Janet Molinari    Corporate  New York City    New York
# ...               ...          ...            ...         ...
# 9947  Helen Wasserman    Corporate   Indianapolis     Indiana
# 9948  Helen Wasserman    Corporate   Indianapolis     Indiana
# 9957    Kristina Nunn  Home Office   New Rochelle    New York
# 9968  Richard Bierner     Consumer     Plainfield  New Jersey
# 9979       Anne Pryor  Home Office    Los Angeles  California
#
#              Category     Sales    Profit
# 1           Furniture   731.940  219.5820
# 13    Office Supplies   407.976  132.5922
# 24          Furniture  1044.630  240.2649
# 35         Technology  1097.544  123.4737
# ...

# %%
df[df['Discount']>0]
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 3          4  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 4          5  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 7          8  CA-2011-115812   09/06/11  14/06/11  Standard Class    BH-11710
# 8          9  CA-2011-115812   09/06/11  14/06/11  Standard Class    BH-11710
# 10        11  CA-2011-115812   09/06/11  14/06/11  Standard Class    BH-11710
# ...      ...             ...        ...       ...             ...         ...
# 9978    9979  US-2013-103674   07/12/13  11/12/13  Standard Class    AP-10720
# 9979    9980  US-2013-103674   07/12/13  11/12/13  Standard Class    AP-10720
# 9981    9982  CA-2014-163566   04/08/14  07/08/14     First Class    TB-21055
# 9989    9990  CA-2011-110422   22/01/11  24/01/11    Second Class    TB-21400
# 9991    9992  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
#
# ...

# %%
df[(df['Sales']>500) &(df['Profit']<0)]
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 3          4  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 27        28  US-2012-150630   17/09/12  21/09/12  Standard Class    TB-21520
# 38        39  CA-2012-117415   27/12/12  31/12/12  Standard Class    SN-20710
# 72        73  US-2012-134026   26/04/12  02/05/12  Standard Class    JE-15745
# 124      125  US-2011-152030   26/12/11  28/12/11    Second Class    AD-10180
# ...      ...             ...        ...       ...             ...         ...
# 9788    9789  CA-2014-144491   28/03/14  02/04/14  Standard Class    CJ-12010
# 9816    9817  CA-2012-162201   08/06/12  12/06/12  Standard Class    AG-10495
# 9876    9877  US-2014-166324   21/04/14  22/04/14     First Class    BE-11455
# 9919    9920  CA-2013-149272   16/03/13  20/03/13  Standard Class    MY-18295
# 9931    9932  CA-2012-104948   13/11/12  17/11/12  Standard Class    KH-16510
#
# ...

# %%
df.sort_values(by='Sales',ascending=False)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 2697    2698  CA-2011-145317   18/03/11  23/03/11  Standard Class    SM-20320
# 6826    6827  CA-2013-118689   03/10/13  10/10/13  Standard Class    TC-20980
# 8153    8154  CA-2014-140151   24/03/14  26/03/14     First Class    RB-19360
# 2623    2624  CA-2014-127180   23/10/14  25/10/14     First Class    TA-21385
# 4190    4191  CA-2014-166709   18/11/14  23/11/14  Standard Class    HL-15040
# ...      ...             ...        ...       ...             ...         ...
# 2106    2107  US-2011-152723   26/09/11  26/09/11        Same Day    HG-14965
# 4711    4712  CA-2011-112403   31/03/11  31/03/11        Same Day    JO-15280
# 8658    8659  CA-2013-168361   22/06/13  26/06/13  Standard Class    KB-16600
# 9292    9293  CA-2014-124114   03/03/14  03/03/14        Same Day    RS-19765
# 4101    4102  US-2014-102288   20/06/14  24/06/14  Standard Class    ZC-21910
#
# ...

# %%
df.sort_values(by='Sales',ascending=True)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 4101    4102  US-2014-102288   20/06/14  24/06/14  Standard Class    ZC-21910
# 9292    9293  CA-2014-124114   03/03/14  03/03/14        Same Day    RS-19765
# 8658    8659  CA-2013-168361   22/06/13  26/06/13  Standard Class    KB-16600
# 4711    4712  CA-2011-112403   31/03/11  31/03/11        Same Day    JO-15280
# 2106    2107  US-2011-152723   26/09/11  26/09/11        Same Day    HG-14965
# ...      ...             ...        ...       ...             ...         ...
# 4190    4191  CA-2014-166709   18/11/14  23/11/14  Standard Class    HL-15040
# 2623    2624  CA-2014-127180   23/10/14  25/10/14     First Class    TA-21385
# 8153    8154  CA-2014-140151   24/03/14  26/03/14     First Class    RB-19360
# 6826    6827  CA-2013-118689   03/10/13  10/10/13  Standard Class    TC-20980
# 2697    2698  CA-2011-145317   18/03/11  23/03/11  Standard Class    SM-20320
#
# ...

# %%
df.sort_values(by=['Category','Sales'],ascending=[True,False])
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 7243    7244  CA-2014-118892   18/08/14  23/08/14    Second Class    TP-21415
# 9741    9742  CA-2012-117086   08/11/12  12/11/12  Standard Class    QJ-19255
# 9639    9640  CA-2012-116638   28/01/12  31/01/12    Second Class    JH-15985
# 5917    5918  US-2012-126977   17/09/12  23/09/12  Standard Class    PF-19120
# 6535    6536  CA-2011-128209   17/11/11  22/11/11  Standard Class    GT-14710
# ...      ...             ...        ...       ...             ...         ...
# 9163    9164  CA-2012-164007   08/06/12  12/06/12  Standard Class    MG-17695
# 7990    7991  US-2013-117793   24/08/13  30/08/13  Standard Class    MA-17560
# 9545    9546  CA-2011-166590   29/10/11  02/11/11  Standard Class    NC-18625
# 7900    7901  CA-2014-128363   14/08/14  19/08/14  Standard Class    DC-12850
# 2761    2762  CA-2014-126536   13/10/14  15/10/14     First Class    NK-18490
#
# ...

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code        0
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# Discount Status    0
# Profit Status      0
# Is Profitable      0
# Sales Per Unit     0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df['Customer ID'].nunique()
# Out:
# 793

# %%
df['Product ID'].nunique()
# Out:
# 1862

# %%
df['City'].nunique()
# Out:
# 531

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
#value_counts

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df['Profit Status'].value_counts()
# Out:
# Profit Status
# Profit    8058
# Loss      1936
# Name: count, dtype: int64

# %%
df['Discount Status'].value_counts()
# Out:
# Discount Status
# Discounted     5196
# No Discount    4798
# Name: count, dtype: int64

# %%
df['Profit_Margin']=(df['Profit']/df['Sales'])*100

# %%
df[['Product Name','Sales','Profit','Profit_Margin']]
# Out:
#                                            Product Name     Sales    Profit  \
# 0                     Bush Somerset Collection Bookcase  261.9600   41.9136
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400  219.5820
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200    6.8714
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775 -383.0310
# 4                        Eldon Fold 'N Roll Cart System   22.3680    2.5164
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480    4.1028
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600   15.6332
# 9991                              Aastra 57i VoIP phone  258.5760   19.3932
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000   13.3200
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600   72.9480
#
#       Profit_Margin
# 0             16.00
# ...

# %%
def seles_level(sales):
    if sales<100:
        return "Low"

    elif sales>=100 and sales<=500:
        return "Medium"

    else:
        return "High"

# %%
df['Sales Level']=df['Sales'].apply(seles_level)

# %%
df
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 1          2  CA-2013-152156   09/11/13  12/11/13    Second Class    CG-12520
# 2          3  CA-2013-138688   13/06/13  17/06/13    Second Class    DV-13045
# 3          4  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# 4          5  US-2012-108966   11/10/12  18/10/12  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2011-110422   22/01/11  24/01/11    Second Class    TB-21400
# 9990    9991  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9991    9992  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9992    9993  CA-2014-121258   27/02/14  04/03/14  Standard Class    DB-13060
# 9993    9994  CA-2014-119914   05/05/14  10/05/14    Second Class    CC-12220
#
# ...

# %% [markdown]
# ## Groupby

# %%
df.groupby('Region')[['Sales','Profit']].sum().sort_values('Profit',ascending=False)
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# Central  501239.8908   39706.3625

# %%
avg_sub_sales=df.groupby('Sub-Category')['Sales'].mean()
avg_sub_sales
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Art              34.068834
# Binders         133.560560
# Bookcases       503.859633
# Chairs          532.332420
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      95.825668
# Labels           34.303055
# Machines       1645.553313
# Paper            57.284092
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
avg_sub_sales[avg_sub_sales>200]
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Bookcases       503.859633
# Chairs          532.332420
# Copiers        2198.941618
# Machines       1645.553313
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
top10=df.groupby(['Customer ID','Customer Name'])['Sales'].sum()

# %%
top10.nlargest(10)
# Out:
# Customer ID  Customer Name
# SM-20320     Sean Miller           25043.050
# TC-20980     Tamara Chand          19052.218
# RB-19360     Raymond Buch          15117.339
# TA-21385     Tom Ashbrook          14595.620
# AB-10105     Adrian Barton         14473.571
# KL-16645     Ken Lonsdale          14175.229
# SC-20095     Sanjit Chand          14142.334
# HL-15040     Hunter Lopez          12873.298
# SE-20110     Sanjit Engle          12209.438
# CC-12370     Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
top10=df.groupby(['Customer ID','Customer Name'])['Profit'].sum()

# %%
top10.nlargest(10)
# Out:
# Customer ID  Customer Name
# TC-20980     Tamara Chand            8981.3239
# RB-19360     Raymond Buch            6976.0959
# SC-20095     Sanjit Chand            5757.4119
# HL-15040     Hunter Lopez            5622.4292
# AB-10105     Adrian Barton           5444.8055
# TA-21385     Tom Ashbrook            4703.7883
# CM-12385     Christopher Martinez    3899.8904
# KD-16495     Keith Dawkins           3038.6254
# AR-10540     Andy Reiter             2884.6208
# DR-12940     Daniel Raglin           2869.0760
# Name: Profit, dtype: float64

# %%
top10.nsmallest(10)
# Out:
# Customer ID  Customer Name
# CS-12505     Cindy Stewart      -6626.3895
# GT-14635     Grant Thornton     -4108.6589
# LF-17185     Luke Foster        -3583.9770
# SR-20425     Sharelle Roach     -3333.9144
# HG-14965     Henry Goldwyn      -2797.9635
# NC-18415     Nathan Cano        -2204.8072
# SB-20290     Sean Braxton       -2082.7451
# SM-20320     Sean Miller        -1980.7393
# CP-12340     Christine Phan     -1850.3029
# NF-18385     Natalie Fritzler   -1695.9714
# Name: Profit, dtype: float64

# %%
result=df.groupby('Category').agg({
    'Sales':['sum','mean'],
    'Profit':['sum','mean'],
    'Quantity':'sum'
})

# %%
print(result)
# Out:
#                        Sales                   Profit            Quantity
#                          sum        mean          sum       mean      sum
# Category
# Furniture        741999.7953  349.834887   18451.2728   8.699327     8028
# Office Supplies  719047.0320  119.324101  122490.8008  20.327050    22906
# Technology       836154.0330  452.709276  145454.9481  78.752002     6939

# %%
df.dtypes
# Out:
# Row ID               int64
# Order ID            object
# Order Date          object
# Ship Date           object
# Ship Mode           object
# Customer ID         object
# Customer Name       object
# Segment             object
# Country             object
# City                object
# State               object
# Postal Code          int64
# Region              object
# Product ID          object
# Category            object
# Sub-Category        object
# Product Name        object
# Sales              float64
# Quantity             int64
# Discount           float64
# Profit             float64
# Discount Status     object
# Profit Status       object
# Is Profitable         bool
# Sales Per Unit     float64
# Profit_Margin      float64
# Sales Level         object
# dtype: object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Order Date'].dt.year
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2012
# 4       2012
#         ...
# 9989    2011
# 9990    2014
# 9991    2014
# 9992    2014
# 9993    2014
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.month
# Out:
# 0        9
# 1        9
# 2        6
# 3       11
# 4       11
#         ..
# 9989     1
# 9990     2
# 9991     2
# 9992     2
# 9993     5
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.month_name()
# Out:
# 0       September
# 1       September
# 2            June
# 3        November
# 4        November
#           ...
# 9989      January
# 9990     February
# 9991     February
# 9992     February
# 9993          May
# Name: Order Date, Length: 9994, dtype: object

# %%
df['Order Date'].dt.day
# Out:
# 0       11
# 1       11
# 2       13
# 3       10
# 4       10
#         ..
# 9989    22
# 9990    27
# 9991    27
# 9992    27
# 9993     5
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.dayofweek
# Out:
# 0       2
# 1       2
# 2       3
# 3       5
# 4       5
#        ..
# 9989    5
# 9990    3
# 9991    3
# 9992    3
# 9993    0
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.day_name()
# Out:
# 0       Wednesday
# 1       Wednesday
# 2        Thursday
# 3        Saturday
# 4        Saturday
#           ...
# 9989     Saturday
# 9990     Thursday
# 9991     Thursday
# 9992     Thursday
# 9993       Monday
# Name: Order Date, Length: 9994, dtype: object

# %%
df['Order Date'].dt.quarter
# Out:
# 0       3
# 1       3
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.quarter
# Out:
# 0       3
# 1       3
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.quarter
# Out:
# 0       3
# 1       3
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.quarter
# Out:
# 0       3
# 1       3
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: Order Date, Length: 9994, dtype: int32

# %%
df['Order Date'].dt.quarter
# Out:
# 0       3
# 1       3
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: Order Date, Length: 9994, dtype: int32

# %%
df.dtypes
# Out:
# Row ID                      int64
# Order ID                   object
# Order Date         datetime64[ns]
# Ship Date                  object
# Ship Mode                  object
# Customer ID                object
# Customer Name              object
# Segment                    object
# Country                    object
# City                       object
# State                      object
# Postal Code                 int64
# Region                     object
# Product ID                 object
# Category                   object
# Sub-Category               object
# Product Name               object
# Sales                     float64
# Quantity                    int64
# Discount                  float64
# Profit                    float64
# Discount Status            object
# Profit Status              object
# Is Profitable                bool
# Sales Per Unit            float64
# Profit_Margin             float64
# Sales Level                object
# dtype: object

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df['Order Year']=df['Order Date'].dt.year
df['Order Month']=df['Order Date'].dt.month
    
df['Order Day']=df['Order Date'].dt.day

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...    Profit  \
# 0      Claire Gute   Consumer  United States        Henderson  ...   41.9136
# 1      Claire Gute   Consumer  United States        Henderson  ...  219.5820
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...    6.8714
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ... -383.0310
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...    2.5164
#
# ...

# %%
df['Order Month Name']=df['Order Date'].dt.month_name()

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Discount Status  Profit Status Is Profitable Sales Per Unit Profit_Margin  \
# ...

# %%
var=df.groupby('Order Month Name')['Sales'].sum()
var
# Out:
# Order Month Name
# April        154316.7811
# August       207760.1943
# December     253639.8997
# February     120374.9094
# January      137587.1322
# July         149362.7248
# June         146105.1243
# March        237482.7502
# May          175243.4649
# November     271461.7345
# October      177756.4052
# September    266109.7397
# Name: Sales, dtype: float64

# %%
var=df.groupby('Order Month Name')['Sales'].sum().idxmax()
var
# Out:
# 'November'

# %%
df['Shipping Days']=df['Ship Date']-df['Order Date']

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Profit Status  Is Profitable Sales Per Unit Profit_Margin Sales Level  \
# ...

# %%
df['Shipping Days'].min()
# Out:
# Timedelta('-320 days +00:00:00')

# %%
table=df.groupby(['Category','Region'])['Profit'].sum()

# %%
table
# Out:
# Category         Region
# Furniture        Central    -2871.0494
#                  East        3046.1658
#                  South       6771.2061
#                  West       11504.9503
# Office Supplies  Central     8879.9799
#                  East       41014.5791
#                  South      19986.3928
#                  West       52609.8490
# Technology       Central    33697.4320
#                  East       47462.0351
#                  South      19991.8314
#                  West       44303.6496
# Name: Profit, dtype: float64

# %%
df.groupby(['Category', 'Region'])['Profit'].sum().reset_index()
# Out:
#            Category   Region      Profit
# 0         Furniture  Central  -2871.0494
# 1         Furniture     East   3046.1658
# 2         Furniture    South   6771.2061
# 3         Furniture     West  11504.9503
# 4   Office Supplies  Central   8879.9799
# 5   Office Supplies     East  41014.5791
# 6   Office Supplies    South  19986.3928
# 7   Office Supplies     West  52609.8490
# 8        Technology  Central  33697.4320
# 9        Technology     East  47462.0351
# 10       Technology    South  19991.8314
# 11       Technology     West  44303.6496

# %%
df.pivot_table(
    index='Category',
    columns='Region',
    values='Profit',
    aggfunc='sum'
)
# Out:
# Region              Central        East       South        West
# Category
# Furniture        -2871.0494   3046.1658   6771.2061  11504.9503
# Office Supplies   8879.9799  41014.5791  19986.3928  52609.8490
# Technology       33697.4320  47462.0351  19991.8314  44303.6496

# %%
df.pivot_table(
    index='Region',
    columns='Category',
    values='Sales',
    aggfunc='sum'
)
# Out:
# Category    Furniture  Office Supplies  Technology
# Region
# Central   163797.1638       167026.415  170416.312
# East      208291.2040       205516.055  264973.981
# South     117298.6840       125651.313  148771.908
# West      252612.7435       220853.249  251991.832

# %%
# most profitable product

# %%
df.groupby('Product Name')['Profit'].sum().nlargest(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
# Ativa V4110MDD Micro-Cut Shredder                                               3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta                                3717.9714
# Plantronics Savi W720 Multi-Device Wireless Headset System                      3696.2820
# Ibico EPK-21 Electric Binding System                                            3345.2823
# Zebra ZM400 Thermal Label Printer                                               3343.5360
# Name: Profit, dtype: float64

# %%
result=df.groupby('Product Name').agg(
    total_Sales=('Sales','sum'),
    total_profit=('Profit','sum')
)

# %%
result[(result['total_Sales']>1000)&(result['total_profit']<0)]
# Out:
#                                                     total_Sales  total_profit
# Product Name
# 3.6 Cubic Foot Counter Height Office Refrigerator     2946.2000     -872.0752
# 3D Systems Cube Printer, 2nd Generation, White        2339.9820     -467.9964
# Atlantic Metals Mobile 4-Shelf Bookcases, Custo...    5184.0810     -126.4410
# BPI Conference Tables                                 2241.8675     -795.9725
# Balt Solid Wood Round Tables                          6518.7540    -1201.0581
# ...                                                         ...           ...
# Tennsco Industrial Shelving                           1281.4420     -108.5802
# Tennsco Regal Shelving Units                          1764.5340       -6.0846
# Tennsco Single-Tier Lockers                           9158.2960     -825.7480
# Tennsco Stur-D-Stor Boltless Shelving, 5 Shelve...    4384.0440      -36.5337
# Xerox WorkCentre 6505DN Laser Multifunction Pri...    2519.9580     -251.9958
#
# ...

# %%
#Q25. Average Profit by Discount Level

# %%
result=df.groupby('Discount').agg(
    Avg_profit=('Profit','mean'),
    record_count=('Profit','count')
)
result
# Out:
#           Avg_profit  record_count
# Discount
# 0.00       66.900292          4798
# 0.10       96.055074            94
# 0.15       27.288298            52
# 0.20       24.702572          3657
# 0.30      -45.679636           227
# 0.32      -88.560656            27
# 0.40     -111.927429           206
# 0.45     -226.646464            11
# 0.50     -310.703456            66
# 0.60      -43.077212           138
# 0.70      -95.874060           418
# 0.80     -101.796797           300

# %%
result=df.groupby('Discount').agg(
    Avg_profit=('Profit','mean'),
    record_count=('Profit','count')
)
result
# Out:
#           Avg_profit  record_count
# Discount
# 0.00       66.900292          4798
# 0.10       96.055074            94
# 0.15       27.288298            52
# 0.20       24.702572          3657
# 0.30      -45.679636           227
# 0.32      -88.560656            27
# 0.40     -111.927429           206
# 0.45     -226.646464            11
# 0.50     -310.703456            66
# 0.60      -43.077212           138
# 0.70      -95.874060           418
# 0.80     -101.796797           300

# %%
profit_margin = df['Profit'].sum()/ df['Sales'].sum() *100

# %%
profit_margin
# Out:
# np.float64(12.467217240315604)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Profit Status  Is Profitable Sales Per Unit Profit_Margin Sales Level  \
# ...

# %%
res=df.groupby('Customer ID').agg(
    orders=('Order ID','count'),
    total_sales=('Sales','sum'),
    total_profit=('Profit','sum')
    
)

# %%
res
# Out:
#              orders  total_sales  total_profit
# Customer ID
# AA-10315         11     5563.560     -362.8825
# AA-10375         15     1056.390      277.3824
# AA-10480         12     1790.512      435.8274
# AA-10645         18     5086.935      857.8033
# AB-10015          6      886.156      129.3465
# ...             ...          ...           ...
# XP-21865         28     2374.658      621.2300
# YC-21895          8     5454.350     1305.6290
# YS-21880         12     6720.444     1778.2923
# ZC-21910         31     8025.707    -1032.1490
# ZD-21925          9     1493.944      249.1307
#
# [793 rows x 3 columns]

# %%
res=res[
    (res['orders']>=10)&
    (res['total_sales']>5000)&
    (res['total_profit']>0)
]

result
# Out:
#           Avg_profit  record_count
# Discount
# 0.00       66.900292          4798
# 0.10       96.055074            94
# 0.15       27.288298            52
# 0.20       24.702572          3657
# 0.30      -45.679636           227
# 0.32      -88.560656            27
# 0.40     -111.927429           206
# 0.45     -226.646464            11
# 0.50     -310.703456            66
# 0.60      -43.077212           138
# 0.70      -95.874060           418
# 0.80     -101.796797           300

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11  Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Profit Status  \
# 0   Claire Gute  Consumer  United States  Henderson  ...        Profit
# 1   Claire Gute  Consumer  United States  Henderson  ...        Profit
#
#    Is Profitable Sales Per Unit Profit_Margin Sales Level Order Year  \
# 0           True         130.98          16.0      Medium       2013
# 1           True         243.98          30.0        High       2013
#
#   Order Month  Order Day  Order Month Name  Shipping Days
# 0           9         11         September        91 days
# 1           9         11         September        91 days
#
# [2 rows x 32 columns]

# %%
res=df.groupby('Customer Name').agg(
    Number_of_Years=('Order Year','nunique'),
    total_sales=('Sales','sum')

    
)
res[res['Number_of_Years']>1]
# Out:
#                     Number_of_Years  total_sales
# Customer Name
# Aaron Bergman                     2      886.156
# Aaron Hawkins                     4     1744.700
# Aaron Smayling                    3     3050.692
# Adam Bellavance                   3     7755.620
# Adam Hart                         4     3250.337
# ...                             ...          ...
# Xylona Preis                      4     2374.658
# Yana Sorensen                     2     6720.444
# Yoseph Carroll                    4     5454.350
# Zuschuss Carroll                  4     8025.707
# Zuschuss Donatelli                3     1493.944
#
# [772 rows x 2 columns]

# %%
rest=df.groupby('Customer Name').agg(
    Number_of_Years=('Order Year','nunique'),
    Total_Sales=('Sales','sum')
)

# %%
rest
# Out:
#                     Number_of_Years  Total_Sales
# Customer Name
# Aaron Bergman                     2      886.156
# Aaron Hawkins                     4     1744.700
# Aaron Smayling                    3     3050.692
# Adam Bellavance                   3     7755.620
# Adam Hart                         4     3250.337
# ...                             ...          ...
# Xylona Preis                      4     2374.658
# Yana Sorensen                     2     6720.444
# Yoseph Carroll                    4     5454.350
# Zuschuss Carroll                  4     8025.707
# Zuschuss Donatelli                3     1493.944
#
# [793 rows x 2 columns]

# %%
rest[rest['Number_of_Years']>1]
# Out:
#                     Number_of_Years  Total_Sales
# Customer Name
# Aaron Bergman                     2      886.156
# Aaron Hawkins                     4     1744.700
# Aaron Smayling                    3     3050.692
# Adam Bellavance                   3     7755.620
# Adam Hart                         4     3250.337
# ...                             ...          ...
# Xylona Preis                      4     2374.658
# Yana Sorensen                     2     6720.444
# Yoseph Carroll                    4     5454.350
# Zuschuss Carroll                  4     8025.707
# Zuschuss Donatelli                3     1493.944
#
# [772 rows x 2 columns]

# %%
sub=df.groupby('Sub-Category').agg(
    Total_Sales=('Sales','sum'),
Total_Profit=('Profit','mean'),
Average_Discount=('Discount','mean'),
Total_Quantity=('Quantity','sum'),
)
sub['Profit_Margin']=(sub['Total_Profit']/sub['Total_Sales'])*100

# %%
sub
# Out:
#               Total_Sales  Total_Profit  Average_Discount  Total_Quantity  \
# Sub-Category
# Accessories   167380.3180     54.111788          0.078452            2976
# Appliances    107532.1610     38.922758          0.166524            1729
# Art            27118.7920      8.200737          0.074874            3000
# Binders       203412.7330     19.843574          0.372292            5974
# Bookcases     114879.9963    -15.230509          0.211140             868
# Chairs        328449.1030     43.095894          0.170178            2356
# Copiers       149528.0300    817.909190          0.161765             234
# Envelopes      16476.4020     27.418019          0.080315             906
# Fasteners       3024.2800      4.375660          0.082028             914
# Furnishings    91705.1640     13.645918          0.138349            3563
# Labels         12486.3120     15.236962          0.068681            1400
# ...

# %%
sub[sub['Total_Profit']<0]
# Out:
#               Total_Sales  Total_Profit  Average_Discount  Total_Quantity  \
# Sub-Category
# Bookcases     114879.9963    -15.230509          0.211140             868
# Supplies       46673.5380     -6.258418          0.076842             647
# Tables        206965.5320    -55.565771          0.261285            1241
#
#               Profit_Margin
# Sub-Category
# Bookcases         -0.013258
# Supplies          -0.013409
# Tables            -0.026848

# %%
states=df.groupby('State').agg(
    Total_Sales=('Sales','sum'),
Total_Profit=('Profit','mean'),
Average_Discount=('Discount','mean'),
Total_Quantity=('Quantity','sum'),
)
sub['Profit_Margin']=(sub['Total_Profit']/sub['Total_Sales'])*100

# %%
states
# Out:
#                       Total_Sales  Total_Profit  Average_Discount  \
# State
# Alabama                19510.6400     94.865989          0.000000
# Arizona                35282.0010    -15.303235          0.303571
# Arkansas               11678.1300     66.811452          0.000000
# California            457687.6315     38.171608          0.072764
# Colorado               32108.1180    -35.867351          0.316484
# Connecticut            13384.3570     42.823071          0.007317
# Delaware               27451.0690    103.930988          0.006250
# District of Columbia    2865.0200    105.958930          0.000000
# Florida                89473.7080     -8.875461          0.299347
# Georgia                49095.8400     88.315453          0.000000
# Idaho                   4382.4860     39.367767          0.085714
# Illinois               80166.1010    -25.625787          0.390041
# Indiana                53555.3600    123.375411          0.000000
# ...

# %%
states.sort_values(by='Total_Sales',ascending=False)
# Out:
#                       Total_Sales  Total_Profit  Average_Discount  \
# State
# California            457687.6315     38.171608          0.072764
# New York              310876.2710     65.637011          0.055319
# Texas                 170188.0458    -26.121174          0.370193
# Washington            138641.2700     66.013146          0.064032
# Pennsylvania          116511.9140    -26.507598          0.328620
# Florida                89473.7080     -8.875461          0.299347
# Illinois               80166.1010    -25.625787          0.390041
# Ohio                   78258.1360    -36.186304          0.324947
# Michigan               76269.6140     95.934069          0.007059
# Virginia               70636.7200     83.026564          0.000000
# North Carolina         55603.1640    -30.083985          0.283534
# Indiana                53555.3600    123.375411          0.000000
# Georgia                49095.8400     88.315453          0.000000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Discount Status', 'Profit Status', 'Is Profitable', 'Sales Per Unit',
#        'Profit_Margin', 'Sales Level', 'Order Year', 'Order Month',
#        'Order Day', 'Order Month Name', 'Shipping Days'],
#       dtype='object')

# %%
sales=df.groupby(['Category','Product Name'])['Sales'].sum().reset_index()

# %%
sales
# Out:
#         Category                                       Product Name     Sales
# 0      Furniture                   12-1/2 Diameter Round Wall Clock   551.448
# 1      Furniture                           24-Hour Round Wall Clock   487.512
# 2      Furniture                           36X48 HARDFLOOR CHAIRMAT   369.248
# 3      Furniture                   3M Hangers With Command Adhesive   108.040
# 4      Furniture                 3M Polarizing Light Filter Sleeves   216.340
# ...          ...                                                ...       ...
# 1837  Technology  iKross Bluetooth Portable Keyboard + Cell Phon...   477.660
# 1838  Technology                         iOttie HLCRIO102 Car Mount   215.892
# 1839  Technology                                iOttie XL Car Mount   223.888
# 1840  Technology  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...   442.554
# 1841  Technology                 netTALK DUO VoIP Telephone Service  1112.788
#
# [1842 rows x 3 columns]

# %%
result=sales.loc[
    sales.groupby('Category')['Sales'].idxmax()
]

# %%
result
# Out:
#              Category                                       Product Name  \
# 206         Furniture       HON 5400 Series Task Chairs for Big and Tall
# 773   Office Supplies  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 1486       Technology              Canon imageCLASS 2200 Advanced Copier
#
#           Sales
# 206   21870.576
# 773   27453.384
# 1486  61599.824

# %%
ff=df.groupby(['Region','Customer Name'])['Profit'].sum().reset_index()

# %%
ff
# Out:
#        Region       Customer Name     Profit
# 0     Central       Aaron Bergman   114.3432
# 1     Central      Aaron Smayling  -251.2959
# 2     Central     Adam Bellavance   115.5072
# 3     Central           Adam Hart    11.9340
# 4     Central  Adam Shillingsburg   274.4242
# ...       ...                 ...        ...
# 2496     West        Xylona Preis   298.3414
# 2497     West       Yana Sorensen  1551.5945
# 2498     West      Yoseph Carroll   382.0575
# 2499     West    Zuschuss Carroll   346.0942
# 2500     West  Zuschuss Donatelli    42.4662
#
# [2501 rows x 3 columns]

# %%
res=ff.loc[
    ff.groupby('Region')['Profit'].idxmax()
]

# %%
res
# Out:
#        Region         Customer Name     Profit
# 579   Central          Tamara Chand  8745.0635
# 916      East          Hunter Lopez  5045.8564
# 1394    South  Christopher Martinez  3197.4580
# 2354     West          Raymond Buch  6807.0879

# %%
loss_percentage=df.groupby('Category')['Profit'].apply(lambda x:(x<0).sum()/len(x)*100)

# %%
loss_percentage
# Out:
# Category
# Furniture          33.663366
# Office Supplies    14.702954
# Technology         14.672442
# Name: Profit, dtype: float64

# %%
loss_per=df.groupby('Category')['Profit'].apply(lambda x:(x<0).sum()/len(x)*100)
loss_per
# Out:
# Category
# Furniture          33.663366
# Office Supplies    14.702954
# Technology         14.672442
# Name: Profit, dtype: float64

# %%
disc=df.groupby('Discount').agg(
    number_of_orders=('Order ID','nunique'),
    total_Sales=('Sales','sum'),
    total_prof=('Profit','sum'),
    Avg_profit=('Profit','mean')
    
)
disc['loss_making_rec_perc']=(
    df.groupby('Discount')['Profit'].apply(lambda x: (x < 0).mean() * 100)
)
disc
# Out:
#           number_of_orders   total_Sales   total_prof  Avg_profit  \
# Discount
# 0.00                  2644  1.087908e+06  320987.6032   66.900292
# 0.10                    89  5.436935e+04    9029.1770   96.055074
# 0.15                    51  2.755852e+04    1418.9915   27.288298
# 0.20                  2407  7.645944e+05   90337.3060   24.702572
# 0.30                   211  1.032267e+05  -10369.2774  -45.679636
# 0.32                    27  1.449346e+04   -2391.1377  -88.560656
# 0.40                   185  1.164178e+05  -23057.0504 -111.927429
# 0.45                    10  5.484974e+03   -2493.1111 -226.646464
# 0.50                    64  5.891854e+04  -20506.4281 -310.703456
# 0.60                   127  6.644700e+03   -5944.6552  -43.077212
# 0.70                   344  4.062028e+04  -40075.3569  -95.874060
# 0.80                   250  1.696376e+04  -30539.0392 -101.796797
#
#           loss_making_rec_perc
# Discount
# 0.00                  0.000000
# ...

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11  Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Profit Status  \
# 0   Claire Gute  Consumer  United States  Henderson  ...        Profit
# 1   Claire Gute  Consumer  United States  Henderson  ...        Profit
#
#    Is Profitable Sales Per Unit Profit_Margin Sales Level Order Year  \
# 0           True         130.98          16.0      Medium       2013
# 1           True         243.98          30.0        High       2013
#
#   Order Month  Order Day  Order Month Name  Shipping Days
# 0           9         11         September        91 days
# 1           9         11         September        91 days
#
# [2 rows x 32 columns]

# %%
final_summary=df.groupby(['Region','Category']).agg(
    Total_sales=('Sales','sum'),
    Total_profit=('Profit','sum'),
    Total_qnt=('Quantity','sum'),
    Avg_dis=('Discount','mean'),
    number_of_orders=('Order ID','nunique')
)
final_summary
# Out:
#                          Total_sales  Total_profit  Total_qnt   Avg_dis  \
# Region  Category
# Central Furniture        163797.1638    -2871.0494       1827  0.297380
#         Office Supplies  167026.4150     8879.9799       5409  0.252743
#         Technology       170416.3120    33697.4320       1544  0.133095
# East    Furniture        208291.2040     3046.1658       2214  0.154077
#         Office Supplies  205516.0550    41014.5791       6462  0.142932
#         Technology       264973.9810    47462.0351       1942  0.143364
# South   Furniture        117298.6840     6771.2061       1291  0.121536
#         Office Supplies  125651.3130    19986.3928       3800  0.167437
#         Technology       148771.9080    19991.8314       1118  0.107850
# West    Furniture        252612.7435    11504.9503       2696  0.131400
#         Office Supplies  220853.2490    52609.8490       7235  0.093358
#         Technology       251991.8320    44303.6496       2335  0.133890
#
# ...

# %%
final_summary['Profit Margin %']=final_summary['Total_profit']/final_summary['Total_sales']*100

# %%
final_summary
# Out:
#                          Total_sales  Total_profit  Total_qnt   Avg_dis  \
# Region  Category
# Central Furniture        163797.1638    -2871.0494       1827  0.297380
#         Office Supplies  167026.4150     8879.9799       5409  0.252743
#         Technology       170416.3120    33697.4320       1544  0.133095
# East    Furniture        208291.2040     3046.1658       2214  0.154077
#         Office Supplies  205516.0550    41014.5791       6462  0.142932
#         Technology       264973.9810    47462.0351       1942  0.143364
# South   Furniture        117298.6840     6771.2061       1291  0.121536
#         Office Supplies  125651.3130    19986.3928       3800  0.167437
#         Technology       148771.9080    19991.8314       1118  0.107850
# West    Furniture        252612.7435    11504.9503       2696  0.131400
#         Office Supplies  220853.2490    52609.8490       7235  0.093358
#         Technology       251991.8320    44303.6496       2335  0.133890
#
# ...

# %%
print("The data is analysed with the pandas")
# Out:
# The data is analysed with the pandas
